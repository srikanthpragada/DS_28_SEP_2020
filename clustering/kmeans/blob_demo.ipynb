# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate synthetic two-dimensional data
X, y = make_blobs(n_samples = 100,random_state=1)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# array([0, 1, 1, 1, 2, 2, 2, 1, 0, 0, 1, 1, 2, 0, 2, 2, 2, 0, 1, 1, 2, 1,
#        2, 0, 1, 2, 2, 0, 0, 2, 0, 0, 2, 0, 1, 2, 1, 1, 1, 2, 2, 1, 0, 1,
#        1, 2, 0, 0, 0, 0, 1, 2, 2, 2, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 1, 2,
#        0, 2, 0, 1, 1, 1, 2, 0, 0, 1, 2, 2, 0, 1, 0, 1, 1, 2, 0, 0, 0, 0,
#        1, 0, 2, 0, 0, 1, 1, 2, 2, 0, 2, 0])

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# Out:
# Text(0, 0.5, 'Feature2')

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
labels
# Out:
# array([0, 2, 2, 2, 1, 1, 1, 2, 0, 0, 2, 2, 1, 0, 1, 1, 1, 0, 2, 2, 1, 2,
#        1, 0, 2, 1, 1, 0, 0, 1, 0, 0, 1, 0, 2, 1, 2, 2, 2, 1, 1, 2, 0, 2,
#        2, 1, 0, 0, 0, 0, 2, 1, 1, 1, 0, 1, 2, 2, 0, 0, 2, 1, 1, 2, 2, 1,
#        0, 1, 0, 2, 2, 2, 1, 0, 0, 2, 1, 1, 0, 2, 0, 2, 2, 1, 0, 0, 0, 0,
#        2, 0, 1, 0, 0, 2, 2, 1, 1, 0, 1, 0])

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ -1.4710815 ,   4.33721882],
#        [ -6.58196786,  -8.17239339],
#        [-10.04935243,  -3.85954095]])

# %%
plt.scatter(X[:,0],X[:,1], c=labels.astype(np.float))
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# draw centers 
plt.scatter(centers[:,0], centers[:,1], c="red", marker="s")
plt.show()

# %%
kmeans.transform(X[:10])
# Out:
# array([[ 2.33264915, 11.79502525, 11.01062651],
#        [11.94628182,  4.2295622 ,  1.30953107],
#        [13.29542634,  6.11688819,  1.51555754],
#        [11.2031992 ,  5.91263769,  0.72516925],
#        [13.1027226 ,  2.05824293,  7.14308111],
#        [13.33464757,  0.32564978,  5.6898446 ],
#        [13.72032135,  0.35951702,  5.89178517],
#        [11.80140588,  4.4505645 ,  1.10800029],
#        [ 1.77075008, 14.24582247, 11.90354354],
#        [ 0.30010589, 13.6239099 , 12.07923924]])

# %%
kmeans.inertia_
# Out:
# 156.28289251170003

# %%
kmeans.n_iter_
# Out:
# 2

# %%
kmeans.score(X)
# Out:
# -156.28289251169932

# %%
cost = []
for k in range(2,6):
   kmeans = KMeans(n_clusters=k)
   kmeans.fit(X)
   cost.append(kmeans.inertia_)

# %%
plt.plot(range(2,6), cost)
plt.xlabel("K")
plt.ylabel("Inertia (Cost)")
# Out:
# Text(0, 0.5, 'Inertia (Cost)')
