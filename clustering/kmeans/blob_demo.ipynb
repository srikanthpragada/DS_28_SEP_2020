# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate synthetic two-dimensional data
X, y = make_blobs(n_samples = 100,random_state=1)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# array([0, 1, 1, 1, 2, 2, 2, 1, 0, 0, 1, 1, 2, 0, 2, 2, 2, 0, 1, 1, 2, 1,
#        2, 0, 1, 2, 2, 0, 0, 2, 0, 0, 2, 0, 1, 2, 1, 1, 1, 2, 2, 1, 0, 1,
#        1, 2, 0, 0, 0, 0, 1, 2, 2, 2, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 1, 2,
#        0, 2, 0, 1, 1, 1, 2, 0, 0, 1, 2, 2, 0, 1, 0, 1, 1, 2, 0, 0, 0, 0,
#        1, 0, 2, 0, 0, 1, 1, 2, 2, 0, 2, 0])

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# Out:
# Text(0, 0.5, 'Feature2')

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
labels = kmeans.labels_
labels
# Out:
# array([1, 2, 2, 2, 0, 0, 0, 2, 1, 1, 2, 2, 0, 1, 0, 0, 0, 1, 2, 2, 0, 2,
#        0, 1, 2, 0, 0, 1, 1, 0, 1, 1, 0, 1, 2, 0, 2, 2, 2, 0, 0, 2, 1, 2,
#        2, 0, 1, 1, 1, 1, 2, 0, 0, 0, 1, 0, 2, 2, 1, 1, 2, 0, 0, 2, 2, 0,
#        1, 0, 1, 2, 2, 2, 0, 1, 1, 2, 0, 0, 1, 2, 1, 2, 2, 0, 1, 1, 1, 1,
#        2, 1, 0, 1, 1, 2, 2, 0, 0, 1, 0, 1])

# %%
# Centroids 
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ -6.58196786,  -8.17239339],
#        [ -1.4710815 ,   4.33721882],
#        [-10.04935243,  -3.85954095]])

# %%
plt.scatter(X[:,0],X[:,1], c=labels.astype(np.float))
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# draw centers 
plt.scatter(centers[:,0], centers[:,1], c="red", marker="s")
plt.show()

# %%
print(kmeans.transform(X[:10]))
print(labels[:10])
# Out:
# [[11.79502525  2.33264915 11.01062651]
#  [ 4.2295622  11.94628182  1.30953107]
#  [ 6.11688819 13.29542634  1.51555754]
#  [ 5.91263769 11.2031992   0.72516925]
#  [ 2.05824293 13.1027226   7.14308111]
#  [ 0.32564978 13.33464757  5.6898446 ]
#  [ 0.35951702 13.72032135  5.89178517]
#  [ 4.4505645  11.80140588  1.10800029]
#  [14.24582247  1.77075008 11.90354354]
#  [13.6239099   0.30010589 12.07923924]]
# [1 2 2 2 0 0 0 2 1 1]

# %%
kmeans.inertia_
# Out:
# 156.28289251170003

# %%
kmeans.n_iter_
# Out:
# 2

# %%
kmeans.score(X)
# Out:
# -156.28289251169932

# %%
cost = []
for k in range(2,6):
   kmeans = KMeans(n_clusters=k)
   kmeans.fit(X)
   cost.append(kmeans.inertia_)

# %%
plt.plot(range(2,6), cost)
plt.xlabel("K")
plt.ylabel("Inertia (Cost)")
# Out:
# Text(0, 0.5, 'Inertia (Cost)')
